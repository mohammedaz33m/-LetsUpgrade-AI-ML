# %% [markdown]
# # Attrition data

# %% [markdown]
# ## Non Parametric Test

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("general_data.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
# 2                 1.0      Y                15              8
# 3                 3.0      Y                11              8
# 4                 4.0      Y                12              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
# 2                 3               5.0                      2               5
# 3                 3              13.0                      5               8
# 4                 2               9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4
#
# [5 rows x 24 columns]

# %%
data.shape
# Out:
# (4410, 24)

# %%
data1 = data.dropna()
data1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
# 2                 1.0      Y                15              8
# 3                 3.0      Y                11              8
# 4                 4.0      Y                12              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
# 2                 3               5.0                      2               5
# 3                 3              13.0                      5               8
# 4                 2               9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4
#
# [5 rows x 24 columns]

# %%
data1.shape
# Out:
# (4382, 24)

# %% [markdown]
# From above shape size we can see that 28 rows has been dropped due to null values (4410-4382 rows)

# %% [markdown]
# .

# %% [markdown]
# ## Chi Square test
#
# To check the dependencies of variables. Only when variables are ___categorical___

# %%
from scipy.stats import chi2_contingency
chitable = pd.crosstab(data1.Attrition,data1.Gender)
stats,p,dof,expected = chi2_contingency(chitable)
print(chitable)

print(stats,p)
# Out:
# Gender     Female  Male
# Attrition
# 0            1488  2189
# 1             268   437
# 1.3825823839528295 0.23966176275638887

# %% [markdown]
#  __H0__: There is no dependencies of attrition (Y/N) on gender.
#
#  __H1__: There is no dependencies of attrition (Y/N) on gender.
#
#
# From the above __p__ value which is __>0.05__ therefore ___Null hypothesis can be accepted___.
#
# Therefore there is No dependency of Attrition(Y/N) on gender.

# %% [markdown]
# .

# %%
# Encoding of the binary values in Attrition as (1,0) from (Yes, No) respectively
from scipy.stats import pearsonr
from sklearn.preprocessing import LabelEncoder as le

# %%
from sklearn import preprocessing
Label_encoder = preprocessing.LabelBinarizer()
data1['Attrition']=Label_encoder.fit_transform(data1['Attrition'])
data1.head()
# Out:
# C:\Users\GV62 7RD\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# 1  Female  ...                 0.0      Y                23              8
# 2    Male  ...                 1.0      Y                15              8
# 3    Male  ...                 3.0      Y                11              8
# 4    Male  ...                 4.0      Y                12              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
# 2                 3               5.0                      2               5
# 3                 3              13.0                      5               8
# 4                 2               9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4
#
# [5 rows x 24 columns]

# %% [markdown]
# .

# %%
data_yes = pd.read_excel("split_data.xlsx",sheet_name=0)
data_no = pd.read_excel("split_data.xlsx",sheet_name=1)

# %%
data_yes.head(3)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   31       Yes  Travel_Frequently  Research & Development                10
# 1   28       Yes      Travel_Rarely  Research & Development                11
# 2   47       Yes         Non-Travel  Research & Development                 1
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          1  Life Sciences              1           2  Female  ...
# 1          2        Medical              1           7    Male  ...
# 2          1        Medical              1          14    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 0.0      Y                23              8
# 1                 2.0      Y                20              8
# 2                 1.0      Y                11              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 1               6.0                      3               5
# 1                 1               5.0                      2               0
# 2                 2              10.0                      4              10
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        1                     4
# 1                        0                     0
# 2                        9                     9
#
# [3 rows x 24 columns]

# %%
data_no.head(3)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   32        No  Travel_Frequently  Research & Development                17
# 2   38        No         Non-Travel  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          4          Other              1           3    Male  ...
# 2          5  Life Sciences              1           4    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 1.0      Y                15              8
# 2                 3.0      Y                11              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 3               5.0                      2               5
# 2                 3              13.0                      5               8
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        0                     3
# 2                        7                     5
#
# [3 rows x 24 columns]

# %% [markdown]
# .

# %% [markdown]
# ### 1. Mannwhitneyu test:
#
# Used to compare two independent samples.

# %%
from scipy.stats import mannwhitneyu

# %% [markdown]
# __H0__: There is no significant difference in DistanceFroHome between Attrition (Y) & Attrition(N)
# __H1__: There is no significant difference in DistanceFroHome between Attrition (Y) & Attrition(N)

# %%
stats,p = mannwhitneyu(data_yes.DistanceFromHome, data_no.DistanceFromHome)
print(stats,p)
# Out:
# 1312110.0 0.4629185205822659

# %% [markdown]
# Since the value of p is >0.05 the ___null hypothesis is accepted___
#
# Therefore, There is no significant difference in DistanceFroHome between Attrition (Y) & Attrition(N)

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # Parametric test
#
# A test where Mean, Mode, Median is used to get the inference on data

# %% [markdown]
# ### 1. one Sample T-test
#
# Here comparision of sample mean is done with the population mean

# %% [markdown]
# ### Assumption mean: Assuming the population mean for monthly salaries is 64000
#
# __H0__ : There is no significant difference between the mean of the salaries of sample against the population mean assumed
#
# __H1__ : There is a significant difference between the mean of the salaries of sample against the population mean assumed

# %%
from scipy.stats import ttest_1samp

# %%
stats,p = ttest_1samp(data1.MonthlyIncome,64000)
print(stats,p)
# Out:
# 1.490830030837023 0.13607811841579942

# %% [markdown]
# From the above p value = 0.13 which is __>0.05__ thus, the ___null hypothesis is accepted___
#
# Therefore,  There is a significant difference between the mean of the salaries of sample against the population mean assumed

# %% [markdown]
# .

# %% [markdown]
# ### 1. Sample independent T-test
#
# Here we compare mean of two independent samples
#
# __H0__ : There is no significant difference in the mean of YearsAtCompany & YearsWithCurrmanager
#
# __H1__ : There is a significant difference in the mean of YearsAtCompany & YearsWithCurrmanager

# %%
from scipy.stats import ttest_ind

# %%
stats,p = ttest_ind(data1.YearsAtCompany, data1.YearsWithCurrManager)
print(stats,p)
# Out:
# 26.918003609662584 2.0706730342875188e-153

# %% [markdown]
# From the above p value which is __<0.05__ thus, the ___null hypothesis is rejected___
#
# Therefore, There is a significant difference in the mean of YearsAtCompany & YearsWithCurrmanager
